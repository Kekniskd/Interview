# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel('Carbon Emission Dataset.xls')

# %%
# dont have data in it
df = df.drop(columns = ['2020', '2021'])

# %%
# duplicate column
df = df.drop(columns = ['1996.1'])

# %%
df_backup = df.copy()

# %%
df = df_backup.copy()

# %%
# how many null 
df.isnull().sum()
# Out:
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1990              33
# 1991              32
# 1992              28
# 1993              28
# 1994              26
# 1995              27
# 1996              27
# 1997              28
# 1998              29
# 1999              29
# 2000              28
# 2001              28
# 2002              27
# 2003              27
# 2004              27
# 2005              27
# 2006              27
# 2007              27
# 2008              27
# 2009              27
# 2010              27
# 2011              27
# 2012              27
# 2013              27
# 2014              28
# 2015              27
# 2016              30
# 2017              30
# 2018              32
# 2019              27
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %%
df.loc[df['1990'].isnull()]
# Out:
#                   Country Name Country Code  \
# 5               American Samoa          ASM
# 12                       Aruba          ABW
# 24                     Bermuda          BMU
# 30      British Virgin Islands          VGB
# 40              Cayman Islands          CYM
# 44             Channel Islands          CHI
# 55                     Curacao          CUW
# 70                     Eritrea          ERI
# 79               Faroe Islands          FRO
# 84            French Polynesia          PYF
# 90                   Gibraltar          GIB
# 92                   Greenland          GRL
# 94                        Guam          GUM
# 103       Hong Kong SAR, China          HKG
# 116                Isle of Man          IMN
# 127                     Kosovo          XKX
# 147           Macao SAR, China          MAC
# 154           Marshall Islands          MHL
# 158      Micronesia, Fed. Sts.          FSM
# 164                     Monaco          MCO
# ...

# %%
# all the rows with null values
df.loc[df.isnull().any(axis=1)]
# Out:
#                     Country Name Country Code  \
# 1    Africa Eastern and Southern          AFE
# 5                 American Samoa          ASM
# 8            Antigua and Barbuda          ATG
# 9                     Arab World          ARB
# 12                         Aruba          ABW
# 18                    Bangladesh          BGD
# 21                       Belgium          BEL
# 24                       Bermuda          BMU
# 27        Bosnia and Herzegovina          BIH
# 30        British Virgin Islands          VGB
# 40                Cayman Islands          CYM
# 44               Channel Islands          CHI
# 46                         China          CHN
# 51                    Costa Rica          CRI
# 55                       Curacao          CUW
# 70                       Eritrea          ERI
# 79                 Faroe Islands          FRO
# 84              French Polynesia          PYF
# 90                     Gibraltar          GIB
# ...

# %%
# getting mean of rows

df.loc[df.isnull().any(axis=1)][['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']].mean(axis=1)
# Out:
# 1         0.960238
# 5              NaN
# 8         5.353169
# 9         3.682849
# 12      100.000000
# 18        0.414097
# 21     1379.805627
# 24        0.000000
# 27       13.540486
# 30             NaN
# 40             NaN
# 44             NaN
# 46        4.362698
# 51        1.417558
# 55             NaN
# 70        0.241845
# 79             NaN
# 84             NaN
# 90             NaN
# 92             NaN
# 94             NaN
# 103            NaN
# 116            NaN
# 127            NaN
# 147            NaN
# 152       0.127156
# 154       2.489367
# 158       1.257997
# 164            NaN
# 170       1.347965
# 174            NaN
# 181            NaN
# 183            NaN
# 189      11.959913
# 199            NaN
# 207            NaN
# 215            NaN
# 229            NaN
# 242       0.308029
# 249            NaN
# 262            NaN
# 263            NaN
# dtype: float64

# %%
df.loc[df.isnull().any(axis=1)] = df.loc[df.isnull().any(axis=1)].fillna(df.loc[df.isnull().any(axis=1)][['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']].mean(axis=1), inplace=True)
# Out:
# C:\Users\kedar\AppData\Local\Temp\ipykernel_26836\2668867192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df.isnull().any(axis=1)] = df.loc[df.isnull().any(axis=1)].fillna(df.loc[df.isnull().any(axis=1)][['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',

# %%
replace null values with mean where data is vailable

df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']] = df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']].fillna(df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']].mean(axis=1))

# %%
# fill all nulls with zero as they dont emmite that much carbon
df = df.fillna(0)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: >

# %%
df3 = df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']]

# %%
df3
# Out:
#          1990      1991      1992      1993      1994      1995      1996  \
# 0    0.222538  0.207535  0.115282  0.095689  0.083465  0.075523  0.068979
# 1    0.982136  0.937815  0.902599  0.904581  0.906340  0.926339  0.936869
# 2    0.473669  0.525418  0.563118  0.518770  0.466821  0.497312  0.559529
# 3    1.819542  1.242810  0.683700  0.638307  0.645355  0.605436  0.612367
# 4    2.466487  2.541909  2.498850  2.640167  2.634856  2.684175  2.626219
# ..        ...       ...       ...       ...       ...       ...       ...
# 263  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 264  3.896327  3.858114  3.801811  3.767891  3.731384  3.780965  3.804548
# 265  0.496444  0.611693  0.632544  0.570455  0.600521  0.653902  0.650041
# 266  0.356474  0.365461  0.352970  0.303473  0.252531  0.245275  0.197708
# 267  1.635374  1.763377  1.735657  1.582226  1.469804  1.408035  1.329377
#
#          1997      1998      1999  ...      2010      2011      2012  \
# ...

# %%
df_trans = df3.transpose()

# %%
df3.boxplot()
# Out:
# <Axes: >

# %%
df_trans.plot(kind='bar',alpha=0.75)
plt.xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
df_trans.plot()
# Out:
# <Axes: >

# %%
df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
       '2017', '2018', '2019']]
# Out:
#          1990      1991      1992      1993      1994      1995      1996  \
# 0    0.222538  0.207535  0.115282  0.095689  0.083465  0.075523  0.068979
# 1    0.982136  0.937815  0.902599  0.904581  0.906340  0.926339  0.936869
# 2    0.473669  0.525418  0.563118  0.518770  0.466821  0.497312  0.559529
# 3    1.819542  1.242810  0.683700  0.638307  0.645355  0.605436  0.612367
# 4    2.466487  2.541909  2.498850  2.640167  2.634856  2.684175  2.626219
# ..        ...       ...       ...       ...       ...       ...       ...
# 263  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 264  3.896327  3.858114  3.801811  3.767891  3.731384  3.780965  3.804548
# 265  0.496444  0.611693  0.632544  0.570455  0.600521  0.653902  0.650041
# 266  0.356474  0.365461  0.352970  0.303473  0.252531  0.245275  0.197708
# 267  1.635374  1.763377  1.735657  1.582226  1.469804  1.408035  1.329377
#
#          1997      1998      1999  ...      2010      2011      2012  \
# ...

# %%
# df[df[['1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019']] > 100]

# outliers which have too much carbon emmission or wrong data
df.loc[df[['1994', '1995', '1996']][(df['1994']>100) | (df['1995']>100) | (df['1996']>100)].index]
# Out:
#               Country Name Country Code  \
# 16            Bahamas, The          BHS
# 17                 Bahrain          BHR
# 20                 Belarus          BLR
# 21                 Belgium          BEL
# 22                  Belize          BLZ
# 26                 Bolivia          BOL
# 27  Bosnia and Herzegovina          BIH
# 29                  Brazil          BRA
# 31       Brunei Darussalam          BRN
# 32                Bulgaria          BGR
#
#                             Indicator Name  Indicator Code       1990  \
# 16  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   7.241049
# 17  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  20.756912
# 20  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   9.797487
# 21  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  10.966775
# 22  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.807338
# 26  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   1.466984
# ...

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                    Afghanistan          AFG
# 1    Africa Eastern and Southern          AFE
# 2     Africa Western and Central          AFW
# 3                        Albania          ALB
# 4                        Algeria          DZA
# ..                           ...          ...
# 263           West Bank and Gaza          PSE
# 264                        World          WLD
# 265                  Yemen, Rep.          YEM
# 266                       Zambia          ZMB
# 267                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code      1990  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.222538
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.982136
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.473669
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.819542
# ...
